# %% [markdown]
# <a href="https://colab.research.google.com/github/mehfujjamadar868-design/DS.BY.HARRY-PYTHON/blob/main/dictionary_%26_its_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dict = {
    "name": "John",
    "age": 36,
    "city":"nyc",
    "mobile number": 1234567890,
}

dict.update({"education" :"b.tech","marks":90})
dict.items()
dict.values()
dict.keys()
#dict["education"]
# Out:
# dict_keys(['name', 'age', 'city', 'mobile number', 'education', 'marks'])

# %%
type(dict)
dict["name"]
# Out:
# 'John'

# %%
dict['age']
# Out:
# 36

# %%
dict['city']
# Out:
# 'nyc'

# %%
dict["mobile number"]
# Out:
# 1234567890

# %%
r = dict.get("name1")#it used to cheack if the value is present in it or not without facing error if the value in it it get show and if not it return NONE
print(r)
# Out:
# None

# %%
dict.items()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11255/2147715289.py in <cell line: 0>()
# ----> 1 dict.items()
#
# TypeError: unbound method dict.items() needs an argument

# %%
print(dict['name'])
# Out:
# John

# %%
dict['age']=22

# %%
dict['age']
# Out:
# 22

# %%
dict.values()
# Out:
# dict_values(['John', 22, 'nyc', 1234567890])

# %%
dict.keys()
# Out:
# dict_keys(['name', 'age', 'city', 'mobile number'])

# %%
dict.update({"education" :"b.tech","marks":90})
dict["education"]
# Out:
# dict['education']

# %%
# Out:
# <class 'dict'>

# %%
# Creating a dictionary using comprehension
squares = {x: x**2 for x in range(1, 12)}
print(squares)  # {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121}

# %%
student = {"name": "Alice", "age": 25, "grade": "A"}

# Adding a new key-value pair
student["city"] = "New York"

# Updating an existing value
student["age"] = 26

# Removing an item
student.pop("grade")

# Iterating over a dictionary
for key, value in student.items():
    print(key, ":", value)

# Output:
# name : Alice
# age : 26
# city : New York
# Out:
# name : Alice
# age : 26
# city : New York
